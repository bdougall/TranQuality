# %%
# !pip install simpletransformers -q
# Out:
#      |████████████████████████████████| 231 kB 4.7 MB/s
#      |████████████████████████████████| 8.3 MB 20.9 MB/s
#      |████████████████████████████████| 43 kB 1.8 MB/s
#      |████████████████████████████████| 290 kB 42.7 MB/s
#      |████████████████████████████████| 3.3 MB 30.0 MB/s
#      |████████████████████████████████| 1.2 MB 35.3 MB/s
#      |████████████████████████████████| 1.7 MB 38.3 MB/s
#      |████████████████████████████████| 3.1 MB 12.3 MB/s
#      |████████████████████████████████| 56 kB 4.1 MB/s
#      |████████████████████████████████| 895 kB 32.1 MB/s
#      |████████████████████████████████| 596 kB 42.4 MB/s
#      |████████████████████████████████| 139 kB 47.7 MB/s
#      |████████████████████████████████| 97 kB 6.6 MB/s
#      |████████████████████████████████| 180 kB 49.2 MB/s
#      |████████████████████████████████| 63 kB 1.4 MB/s
#      |████████████████████████████████| 243 kB 53.8 MB/s
#      |████████████████████████████████| 1.1 MB 35.6 MB/s
#      |████████████████████████████████| 125 kB 46.2 MB/s
#      |████████████████████████████████| 192 kB 52.6 MB/s
#      |████████████████████████████████| 271 kB 40.5 MB/s
#      |████████████████████████████████| 160 kB 47.8 MB/s
#      |████████████████████████████████| 111 kB 52.4 MB/s
#      |████████████████████████████████| 4.3 MB 23.4 MB/s
#      |████████████████████████████████| 76 kB 5.1 MB/s
#      |████████████████████████████████| 125 kB 51.8 MB/s
#      |████████████████████████████████| 790 kB 34.4 MB/s
#      |████████████████████████████████| 374 kB 34.5 MB/s
#   Building wheel for subprocess32 (setup.py) ... done
#   Building wheel for pathtools (setup.py) ... done
#   Building wheel for seqeval (setup.py) ... done
#   Building wheel for blinker (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# jupyter-console 5.2.0 requires prompt-toolkit<2.0.0,>=1.0.0, but you have prompt-toolkit 3.0.21 which is incompatible.
# google-colab 1.0.0 requires ipykernel~=4.10, but you have ipykernel 6.5.0 which is incompatible.
# google-colab 1.0.0 requires ipython~=5.5.0, but you have ipython 7.29.0 which is incompatible.

# %%
import logging
import pandas as pd
from simpletransformers.t5 import T5Model, T5Args

# %%
# Mount Google drive to upload datasets
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# The path to the data on my drive
D = '/content/drive/My Drive/W266_Project_Data/pmi_data'

# %%
# Set up logging 
logging.basicConfig(level=logging.INFO)
mt5_logger = logging.getLogger("transformers")
mt5_logger.setLevel(logging.WARNING)

# %%
# Load the training and evaluation datasets
# Cast each to a string since MT5 is a sequence to sequence model which expects inputs and outputs to be strings of text
train_df = pd.read_csv(D+"/train/en_bn_te.csv").astype(str)
eval_df = pd.read_csv(D+"/dev/en_bn_te.csv").astype(str)

# %%
# Rename the source column so that it matches the expected field name
train_df.rename(columns={'source_text': 'input_text'}, inplace=True)
train_df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
# Rename the source column so that it matches the expected field name
eval_df.rename(columns={'source_text': 'input_text'}, inplace=True)
eval_df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
# Set the training parameters for the MT5 model
model_args = T5Args()
model_args.max_seq_length = 196
# Pick a low batch number for memory for training and testing
model_args.train_batch_size = 8
model_args.eval_batch_size = 8
model_args.num_train_epochs = 1
model_args.evaluate_during_training = False
model_args.use_multiprocessing = False
model_args.fp16 = False
model_args.save_steps = -1
model_args.save_eval_checkpoints = False
model_args_save_model_every_epoch = False
model_args.no_cache = True
model_args_reprocess_input_data = True
model_args_overwrite_output_dir = True
model_args.num_return_sequences = 1
model_args.wandb_project = "MT5-multiple-translator"

# %%
# Create an instance of the model
model = T5Model("mt5", "google/mt5-small", args=model_args)
# Out:
# Downloading:   0%|          | 0.00/4.11M [00:00<?, ?B/s]
# DEBUG:filelock:Attempting to release lock 140322413014032 on /root/.cache/huggingface/transformers/37d0f67f084f8c5fc5589e0bba5ff3c6307af833bb0b7f4eb33fbfd8d4038a9d.84ea7af2df68dc8db434d3160aab65cce8ac63ce5b6f7743f8c9a4a14b4f77e2.lock
# DEBUG:filelock:Lock 140322413014032 released on /root/.cache/huggingface/transformers/37d0f67f084f8c5fc5589e0bba5ff3c6307af833bb0b7f4eb33fbfd8d4038a9d.84ea7af2df68dc8db434d3160aab65cce8ac63ce5b6f7743f8c9a4a14b4f77e2.lock
# DEBUG:filelock:Attempting to acquire lock 140322413013072 on /root/.cache/huggingface/transformers/685ac0ca8568ec593a48b61b0a3c272beee9bc194a3c7241d15dcadb5f875e53.f76030f3ec1b96a8199b2593390c610e76ca8028ef3d24680000619ffb646276.lock
# DEBUG:filelock:Lock 140322413013072 acquired on /root/.cache/huggingface/transformers/685ac0ca8568ec593a48b61b0a3c272beee9bc194a3c7241d15dcadb5f875e53.f76030f3ec1b96a8199b2593390c610e76ca8028ef3d24680000619ffb646276.lock
# Downloading:   0%|          | 0.00/99.0 [00:00<?, ?B/s]
# DEBUG:filelock:Attempting to release lock 140322413013072 on /root/.cache/huggingface/transformers/685ac0ca8568ec593a48b61b0a3c272beee9bc194a3c7241d15dcadb5f875e53.f76030f3ec1b96a8199b2593390c610e76ca8028ef3d24680000619ffb646276.lock
# DEBUG:filelock:Lock 140322413013072 released on /root/.cache/huggingface/transformers/685ac0ca8568ec593a48b61b0a3c272beee9bc194a3c7241d15dcadb5f875e53.f76030f3ec1b96a8199b2593390c610e76ca8028ef3d24680000619ffb646276.lock
# DEBUG:filelock:Attempting to acquire lock 140322413153872 on /root/.cache/huggingface/transformers/6a9e52d6dd21568e37b65fc180ada927968e8f7124f0acd6efcaf90cd2e0f4bb.4b81e5d952ad810ca1de2b3e362b9a26a5cc77b4b75daf20caf69fb838751c32.lock
# DEBUG:filelock:Lock 140322413153872 acquired on /root/.cache/huggingface/transformers/6a9e52d6dd21568e37b65fc180ada927968e8f7124f0acd6efcaf90cd2e0f4bb.4b81e5d952ad810ca1de2b3e362b9a26a5cc77b4b75daf20caf69fb838751c32.lock
# Downloading:   0%|          | 0.00/82.0 [00:00<?, ?B/s]
# DEBUG:filelock:Attempting to release lock 140322413153872 on /root/.cache/huggingface/transformers/6a9e52d6dd21568e37b65fc180ada927968e8f7124f0acd6efcaf90cd2e0f4bb.4b81e5d952ad810ca1de2b3e362b9a26a5cc77b4b75daf20caf69fb838751c32.lock
# DEBUG:filelock:Lock 140322413153872 released on /root/.cache/huggingface/transformers/6a9e52d6dd21568e37b65fc180ada927968e8f7124f0acd6efcaf90cd2e0f4bb.4b81e5d952ad810ca1de2b3e362b9a26a5cc77b4b75daf20caf69fb838751c32.lock

# %%
# Train the model
model.train_model(train_df, eval_data=eval_df)
# Out:
# INFO:simpletransformers.t5.t5_utils: Creating features from dataset file at cache_dir/
#   0%|          | 0/56686 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:3407: FutureWarning:
# `prepare_seq2seq_batch` is deprecated and will be removed in version 5 of HuggingFace Transformers. Use the regular
# `__call__` method to prepare your inputs and the tokenizer under the `as_target_tokenizer` context manager to prepare
# your targets.
#
# Here is a short example:
#
# model_inputs = tokenizer(src_texts, ...)
# with tokenizer.as_target_tokenizer():
#     labels = tokenizer(tgt_texts, ...)
# model_inputs["labels"] = labels["input_ids"]
#
# See the documentation of your specific tokenizer for more details on the specific arguments to the tokenizer of choice.
# For a more complete example, see the implementation of `prepare_seq2seq_batch`.
#
#   warnings.warn(formatted_warning, FutureWarning)
# INFO:simpletransformers.t5.t5_model: Training started
# Using Adafactor for T5
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
#                     Syncing run <strong><a href="https://wandb.ai/bdougall/MT5-multiple-translator/runs/rz2fi9wm" target="_blank">rare-butterfly-1</a></strong> to <a href="https://wandb.ai/bdougall/MT5-multiple-translator" target="_blank">Weights & Biases</a> (<a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">docs</a>).<br/>
# Running Epoch 0 of 1:   0%|          | 0/7086 [00:00<?, ?it/s]
# INFO:simpletransformers.t5.t5_model: Training of google/mt5-small model complete. Saved to outputs/.
# (7086, 3.4033266836022915)

# %%
# Import PyTorch to save the model
import torch

# %%
torch.save(model, '/content/drive/My Drive/W266_Project_Data/models/MT5/checkpoints/mycheckpoint/mt5_indic.pt')

# %%
# Get the evaluation data for testing
to_predict = [prefix + ": " + str(input_text) for prefix, input_text in zip(eval_df['prefix'].tolist(), eval_df['input_text'].tolist())]

# Get the actual translations and tasks
truth = eval_df["target_text"].tolist()
tasks = eval_df["prefix"].tolist()

# %%
# Get the model predicted values
preds = model.predict(to_predict)
# Out:
# Generating outputs:   0%|          | 0/250 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:3407: FutureWarning:
# `prepare_seq2seq_batch` is deprecated and will be removed in version 5 of HuggingFace Transformers. Use the regular
# `__call__` method to prepare your inputs and the tokenizer under the `as_target_tokenizer` context manager to prepare
# your targets.
#
# Here is a short example:
#
# model_inputs = tokenizer(src_texts, ...)
# with tokenizer.as_target_tokenizer():
#     labels = tokenizer(tgt_texts, ...)
# model_inputs["labels"] = labels["input_ids"]
#
# See the documentation of your specific tokenizer for more details on the specific arguments to the tokenizer of choice.
# For a more complete example, see the implementation of `prepare_seq2seq_batch`.
#
#   warnings.warn(formatted_warning, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9f5c79ddd0> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# Decoding outputs:   0%|          | 0/2000 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9f5c79dcb0> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9edb56a320> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9edb591b90> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9edb592e60> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9edb592f80> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda877320> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda877170> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda8775f0> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda8779e0> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda877b90> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda877d40> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda877ef0> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda86a0e0> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda86a290> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda86a440> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda86a5f0> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda86a7a0> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda86a950> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda86ab00> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda86acb0> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda86ae60> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda864050> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda864200> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda8643b0> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda864560> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda864710> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda8648c0> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda864a70> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda864c20> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda864dd0> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda864f80> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda862170> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda862320> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda8624d0> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda862680> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda862830> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda8629e0> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda862b90> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda862d40> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda862ef0> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda8470e0> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda847290> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda847440> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda8475f0> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda8477a0> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda847950> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda847b00> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda847cb0> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda847e60> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda848050> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda848200> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda8483b0> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda848560> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda848710> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda8488c0> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda848a70> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda848c20> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda848dd0> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda848f80> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda84a170> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda84a320> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda84a4d0> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda84a680> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda84a830> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda84a9e0> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda84ab90> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda84ad40> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda84aef0> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda84e0e0> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda84e290> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda84e440> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda84e5f0> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda84e7a0> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda84e950> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda84eb00> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda84ecb0> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda84ee60> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda850050> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda850200> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda8503b0> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda850560> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda850710> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda8508c0> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda850a70> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda850c20> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda850dd0> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda850f80> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda854170> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda854320> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda8544d0> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda854680> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda854830> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda8549e0> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda854b90> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda854d40> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda854ef0> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda8560e0> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda856290> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda856440> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda8565f0> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda8567a0> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda856950> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda856b00> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda856cb0> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda856e60> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda85a050> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda85a200> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda85a3b0> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda85a560> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda85a710> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda85a8c0> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda85aa70> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda85ac20> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda85add0> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda85af80> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda7fe170> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda7fe320> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda7fe4d0> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda7fe680> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda7fe830> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda7fe9e0> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# ...
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda8089e0> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda808b90> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda808d40> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda808ef0> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda80c0e0> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda80c290> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda80c440> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda80c5f0> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda80c7a0> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda80c950> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda80cb00> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda80ccb0> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda80ce60> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda811050> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda811200> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda8113b0> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda811560> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda811710> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda8118c0> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda811a70> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda811c20> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda811dd0> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda811f80> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda814170> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda814320> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda8144d0> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda814680> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda814830> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda8149e0> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda814b90> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda814d40> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda814ef0> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda8170e0> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda817290> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda817440> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda8175f0> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda8177a0> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda817950> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda817b00> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda817cb0> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))
# /usr/local/lib/python3.7/dist-packages/torch/utils/hooks.py:62: UserWarning: backward hook <function TorchHistory._hook_variable_gradient_stats.<locals>.<lambda> at 0x7f9eda817e60> on tensor will not be serialized.  If this is expected, you can decorate the function with @torch.utils.hooks.unserializable_hook to suppress this warning
#   "to suppress this warning".format(repr(hook)))

# %%
eval_df.columns
# Out:
# Index(['prefix', 'input_text', 'target_text'], dtype='object')

# %%
# Create a file of the translation task, actual text, and predicted text
df = pd.DataFrame({'prefix': eval_df.prefix.tolist(), 
                   'target_text': eval_df.target_text.tolist(), 'predicted_text': preds})

# %%
# Save the translations to a csv file
df.to_csv(D+'/predicted_text/english_to_te_and_bn.csv')
